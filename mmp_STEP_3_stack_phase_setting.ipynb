# %% [markdown]
# # Setting of stack phase

# %% [markdown]
# At this phase we are going to set the stacked-phase dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from utils.trainFold import loadColumnsCategorical

# %%
import sys
sys.path.append('../dsbase/src/main')
from AdaBoostClassificationDSBase import AdaBoostClassificationDSBaseModel

# %% [markdown]
# ## Loading the original stacked dataset and shuffle it

# %%
df = pd.read_csv('datasets/train_stack.csv')

# %%
df_frac = df.sample(frac=0.30)

# %%
df_frac.shape
# Out:
# (8149, 77)

# %% [markdown]
# ## Defining the Fold X processing

# %%
def getColumnFoldX(df, fold_id):
    # Convert every element to a one-elenet List
    print('   dataframe to list ...')
    df_w = df.drop(['MachineIdentifier','HasDetections','fold'], axis=1)
    columns_categorical = df_w.select_dtypes(include=['object']).columns

    # Comluns transformation
    df_end = loadColumnsCategorical(fold_id, df_w, columns_categorical)
    
    # --------------------------------------
    # Load the i-th model and process
    print('   loading model ...')    
    model = AdaBoostClassificationDSBaseModel('AB2',None,None,None,None,None,None)
    model.load('models/fold' + str(fold_id))
    
    print('   Calculating: normalization ...')    
    pre_result = model.scalerX.transform(df_end.values)
    print('   Calculating: probabilities ...')    
    result = model.model.predict_proba(pre_result)
    
    # Set the result as a one-column DataFrame
    print('   Creating result dataset ...')        
    columns_name = [str('f' + str(fold_id))]
    df_result = pd.DataFrame(result[:,1])
    df_result.columns = columns_name
    return df_result

# %% [markdown]
# ## Lets obtain the final stacked dataset

# %%
N = 9 # Number of folds
df_stack_set = df_frac.reset_index(drop=True)
for i in range(9):
    print('processing fold ' + str(i+1) + " ...")
    c = getColumnFoldX(df_frac, i+1)
    df_stack_set = df_stack_set.join(c)
# Out:
# processing fold 1 ...
#    dataframe to list ...
#    column "ProductName" transformation ...
#    column "EngineVersion" transformation ...
#    column "AppVersion" transformation ...
#    column "AvSigVersion" transformation ...
#    column "Platform" transformation ...
#    column "Processor" transformation ...
#    column "OsVer" transformation ...
#    column "OsPlatformSubRelease" transformation ...
#    column "OsBuildLab" transformation ...
#    column "SkuEdition" transformation ...
#    column "SmartScreen" transformation ...
#    column "Census_MDC2FormFactor" transformation ...
#    column "Census_DeviceFamily" transformation ...
#    column "Census_PrimaryDiskTypeName" transformation ...
#    column "Census_ChassisTypeName" transformation ...
#    column "Census_PowerPlatformRoleName" transformation ...
#    column "Census_OSVersion" transformation ...
#    column "Census_OSArchitecture" transformation ...
#    column "Census_OSBranch" transformation ...
#    column "Census_OSEdition" transformation ...
#    column "Census_OSSkuName" transformation ...
#    column "Census_OSInstallTypeName" transformation ...
#    column "Census_OSWUAutoUpdateOptionsName" transformation ...
#    column "Census_GenuineStateName" transformation ...
#    column "Census_ActivationChannel" transformation ...
#    column "Census_FlightRing" transformation ...
#    loading model ...
# initiating empty model AB2. AdaBoostClassification
# loading model: models/fold1/AdaBoostClassification_AB2.sav
#    Calculating: normalization ...
# /anaconda3/lib/python3.6/site-packages/sklearn/base.py:311: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.20.2 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/base.py:311: UserWarning: Trying to unpickle estimator AdaBoostClassifier from version 0.20.2 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/base.py:311: UserWarning: Trying to unpickle estimator MinMaxScaler from version 0.20.2 when using version 0.19.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
#    Calculating: probabilities ...
#    Creating result dataset ...
# processing fold 2 ...
#    dataframe to list ...
#    column "ProductName" transformation ...
#    column "EngineVersion" transformation ...
#    column "AppVersion" transformation ...
#    column "AvSigVersion" transformation ...
#    column "Platform" transformation ...
#    column "Processor" transformation ...
#    column "OsVer" transformation ...
#    column "OsPlatformSubRelease" transformation ...
#    column "OsBuildLab" transformation ...
#    column "SkuEdition" transformation ...
#    column "SmartScreen" transformation ...
#    column "Census_MDC2FormFactor" transformation ...
#    column "Census_DeviceFamily" transformation ...
#    column "Census_PrimaryDiskTypeName" transformation ...
#    column "Census_ChassisTypeName" transformation ...
#    column "Census_PowerPlatformRoleName" transformation ...
#    column "Census_OSVersion" transformation ...
#    column "Census_OSArchitecture" transformation ...
#    column "Census_OSBranch" transformation ...
#    column "Census_OSEdition" transformation ...
#    column "Census_OSSkuName" transformation ...
#    column "Census_OSInstallTypeName" transformation ...
#    column "Census_OSWUAutoUpdateOptionsName" transformation ...
#    column "Census_GenuineStateName" transformation ...
#    column "Census_ActivationChannel" transformation ...
#    column "Census_FlightRing" transformation ...
#    loading model ...
# initiating empty model AB2. AdaBoostClassification
# loading model: models/fold2/AdaBoostClassification_AB2.sav
#    Calculating: normalization ...
#    Calculating: probabilities ...
#    Creating result dataset ...
# processing fold 3 ...
#    dataframe to list ...
#    column "ProductName" transformation ...
#    column "EngineVersion" transformation ...
#    column "AppVersion" transformation ...
#    column "AvSigVersion" transformation ...
#    column "Platform" transformation ...
#    column "Processor" transformation ...
#    column "OsVer" transformation ...
#    column "OsPlatformSubRelease" transformation ...
#    column "OsBuildLab" transformation ...
#    column "SkuEdition" transformation ...
#    column "SmartScreen" transformation ...
#    column "Census_MDC2FormFactor" transformation ...
#    column "Census_DeviceFamily" transformation ...
#    column "Census_PrimaryDiskTypeName" transformation ...
#    column "Census_ChassisTypeName" transformation ...
#    column "Census_PowerPlatformRoleName" transformation ...
#    column "Census_OSVersion" transformation ...
#    column "Census_OSArchitecture" transformation ...
#    column "Census_OSBranch" transformation ...
#    column "Census_OSEdition" transformation ...
#    column "Census_OSSkuName" transformation ...
#    column "Census_OSInstallTypeName" transformation ...
#    column "Census_OSWUAutoUpdateOptionsName" transformation ...
#    column "Census_GenuineStateName" transformation ...
#    column "Census_ActivationChannel" transformation ...
#    column "Census_FlightRing" transformation ...
#    loading model ...
# initiating empty model AB2. AdaBoostClassification
# loading model: models/fold3/AdaBoostClassification_AB2.sav
#    Calculating: normalization ...
#    Calculating: probabilities ...
#    Creating result dataset ...
# processing fold 4 ...
#    dataframe to list ...
#    column "ProductName" transformation ...
#    column "EngineVersion" transformation ...
#    column "AppVersion" transformation ...
#    column "AvSigVersion" transformation ...
#    column "Platform" transformation ...
#    column "Processor" transformation ...
#    column "OsVer" transformation ...
#    column "OsPlatformSubRelease" transformation ...
#    column "OsBuildLab" transformation ...
#    column "SkuEdition" transformation ...
#    column "SmartScreen" transformation ...
#    column "Census_MDC2FormFactor" transformation ...
#    column "Census_DeviceFamily" transformation ...
#    column "Census_PrimaryDiskTypeName" transformation ...
#    column "Census_ChassisTypeName" transformation ...
#    column "Census_PowerPlatformRoleName" transformation ...
#    column "Census_OSVersion" transformation ...
#    column "Census_OSArchitecture" transformation ...
#    column "Census_OSBranch" transformation ...
#    column "Census_OSEdition" transformation ...
#    column "Census_OSSkuName" transformation ...
#    column "Census_OSInstallTypeName" transformation ...
#    column "Census_OSWUAutoUpdateOptionsName" transformation ...
#    column "Census_GenuineStateName" transformation ...
#    column "Census_ActivationChannel" transformation ...
#    column "Census_FlightRing" transformation ...
#    loading model ...
# initiating empty model AB2. AdaBoostClassification
# loading model: models/fold4/AdaBoostClassification_AB2.sav
#    Calculating: normalization ...
#    Calculating: probabilities ...
#    Creating result dataset ...
# processing fold 5 ...
#    dataframe to list ...
#    column "ProductName" transformation ...
#    column "EngineVersion" transformation ...
#    column "AppVersion" transformation ...
#    column "AvSigVersion" transformation ...
#    column "Platform" transformation ...
#    column "Processor" transformation ...
#    column "OsVer" transformation ...
#    column "OsPlatformSubRelease" transformation ...
#    column "OsBuildLab" transformation ...
#    column "SkuEdition" transformation ...
#    column "SmartScreen" transformation ...
#    column "Census_MDC2FormFactor" transformation ...
#    column "Census_DeviceFamily" transformation ...
#    column "Census_PrimaryDiskTypeName" transformation ...
#    column "Census_ChassisTypeName" transformation ...
#    column "Census_PowerPlatformRoleName" transformation ...
#    column "Census_OSVersion" transformation ...
#    column "Census_OSArchitecture" transformation ...
#    column "Census_OSBranch" transformation ...
#    column "Census_OSEdition" transformation ...
#    column "Census_OSSkuName" transformation ...
#    column "Census_OSInstallTypeName" transformation ...
#    column "Census_OSWUAutoUpdateOptionsName" transformation ...
#    column "Census_GenuineStateName" transformation ...
#    column "Census_ActivationChannel" transformation ...
#    column "Census_FlightRing" transformation ...
#    loading model ...
# initiating empty model AB2. AdaBoostClassification
# loading model: models/fold5/AdaBoostClassification_AB2.sav
#    Calculating: normalization ...
#    Calculating: probabilities ...
#    Creating result dataset ...
# processing fold 6 ...
#    dataframe to list ...
#    column "ProductName" transformation ...
#    column "EngineVersion" transformation ...
#    column "AppVersion" transformation ...
#    column "AvSigVersion" transformation ...
#    column "Platform" transformation ...
#    column "Processor" transformation ...
#    column "OsVer" transformation ...
#    column "OsPlatformSubRelease" transformation ...
#    column "OsBuildLab" transformation ...
#    column "SkuEdition" transformation ...
#    column "SmartScreen" transformation ...
#    column "Census_MDC2FormFactor" transformation ...
#    column "Census_DeviceFamily" transformation ...
#    column "Census_PrimaryDiskTypeName" transformation ...
#    column "Census_ChassisTypeName" transformation ...
#    column "Census_PowerPlatformRoleName" transformation ...
#    column "Census_OSVersion" transformation ...
#    column "Census_OSArchitecture" transformation ...
#    column "Census_OSBranch" transformation ...
#    column "Census_OSEdition" transformation ...
#    column "Census_OSSkuName" transformation ...
#    column "Census_OSInstallTypeName" transformation ...
#    column "Census_OSWUAutoUpdateOptionsName" transformation ...
#    column "Census_GenuineStateName" transformation ...
#    column "Census_ActivationChannel" transformation ...
#    column "Census_FlightRing" transformation ...
#    loading model ...
# initiating empty model AB2. AdaBoostClassification
# loading model: models/fold6/AdaBoostClassification_AB2.sav
#    Calculating: normalization ...
#    Calculating: probabilities ...
#    Creating result dataset ...
# processing fold 7 ...
#    dataframe to list ...
#    column "ProductName" transformation ...
#    column "EngineVersion" transformation ...
#    column "AppVersion" transformation ...
#    column "AvSigVersion" transformation ...
#    column "Platform" transformation ...
#    column "Processor" transformation ...
#    column "OsVer" transformation ...
#    column "OsPlatformSubRelease" transformation ...
#    column "OsBuildLab" transformation ...
#    column "SkuEdition" transformation ...
#    column "SmartScreen" transformation ...
#    column "Census_MDC2FormFactor" transformation ...
#    column "Census_DeviceFamily" transformation ...
#    column "Census_PrimaryDiskTypeName" transformation ...
#    column "Census_ChassisTypeName" transformation ...
#    column "Census_PowerPlatformRoleName" transformation ...
#    column "Census_OSVersion" transformation ...
#    column "Census_OSArchitecture" transformation ...
#    column "Census_OSBranch" transformation ...
#    column "Census_OSEdition" transformation ...
#    column "Census_OSSkuName" transformation ...
#    column "Census_OSInstallTypeName" transformation ...
#    column "Census_OSWUAutoUpdateOptionsName" transformation ...
#    column "Census_GenuineStateName" transformation ...
#    column "Census_ActivationChannel" transformation ...
#    column "Census_FlightRing" transformation ...
#    loading model ...
# initiating empty model AB2. AdaBoostClassification
# loading model: models/fold7/AdaBoostClassification_AB2.sav
#    Calculating: normalization ...
#    Calculating: probabilities ...
#    Creating result dataset ...
# processing fold 8 ...
#    dataframe to list ...
#    column "ProductName" transformation ...
#    column "EngineVersion" transformation ...
#    column "AppVersion" transformation ...
#    column "AvSigVersion" transformation ...
#    column "Platform" transformation ...
#    column "Processor" transformation ...
#    column "OsVer" transformation ...
#    column "OsPlatformSubRelease" transformation ...
#    column "OsBuildLab" transformation ...
#    column "SkuEdition" transformation ...
#    column "SmartScreen" transformation ...
#    column "Census_MDC2FormFactor" transformation ...
#    column "Census_DeviceFamily" transformation ...
#    column "Census_PrimaryDiskTypeName" transformation ...
#    column "Census_ChassisTypeName" transformation ...
#    column "Census_PowerPlatformRoleName" transformation ...
#    column "Census_OSVersion" transformation ...
#    column "Census_OSArchitecture" transformation ...
#    column "Census_OSBranch" transformation ...
#    column "Census_OSEdition" transformation ...
#    column "Census_OSSkuName" transformation ...
#    column "Census_OSInstallTypeName" transformation ...
#    column "Census_OSWUAutoUpdateOptionsName" transformation ...
#    column "Census_GenuineStateName" transformation ...
#    column "Census_ActivationChannel" transformation ...
#    column "Census_FlightRing" transformation ...
#    loading model ...
# initiating empty model AB2. AdaBoostClassification
# loading model: models/fold8/AdaBoostClassification_AB2.sav
#    Calculating: normalization ...
#    Calculating: probabilities ...
#    Creating result dataset ...
# processing fold 9 ...
#    dataframe to list ...
#    column "ProductName" transformation ...
#    column "EngineVersion" transformation ...
#    column "AppVersion" transformation ...
#    column "AvSigVersion" transformation ...
#    column "Platform" transformation ...
#    column "Processor" transformation ...
#    column "OsVer" transformation ...
#    column "OsPlatformSubRelease" transformation ...
#    column "OsBuildLab" transformation ...
#    column "SkuEdition" transformation ...
#    column "SmartScreen" transformation ...
#    column "Census_MDC2FormFactor" transformation ...
#    column "Census_DeviceFamily" transformation ...
#    column "Census_PrimaryDiskTypeName" transformation ...
#    column "Census_ChassisTypeName" transformation ...
#    column "Census_PowerPlatformRoleName" transformation ...
#    column "Census_OSVersion" transformation ...
#    column "Census_OSArchitecture" transformation ...
#    column "Census_OSBranch" transformation ...
#    column "Census_OSEdition" transformation ...
#    column "Census_OSSkuName" transformation ...
#    column "Census_OSInstallTypeName" transformation ...
#    column "Census_OSWUAutoUpdateOptionsName" transformation ...
#    column "Census_GenuineStateName" transformation ...
#    column "Census_ActivationChannel" transformation ...
#    column "Census_FlightRing" transformation ...
#    loading model ...
# initiating empty model AB2. AdaBoostClassification
# loading model: models/fold9/AdaBoostClassification_AB2.sav
#    Calculating: normalization ...
#    Calculating: probabilities ...
#    Creating result dataset ...

# %%
df_stack_set[['HasDetections','fold','f1','f2','f3','f4','f5','f6','f7','f8','f9']].describe()
# Out:
#        HasDetections         fold           f1           f2           f3  \
# count     8149.00000  8149.000000  8149.000000  8149.000000  8149.000000
# mean         0.52215     4.998282     0.492093     0.490112     0.495558
# std          0.49954     2.582226     0.000838     0.001981     0.003637
# min          0.00000     1.000000     0.488962     0.486171     0.486790
# 25%          0.00000     3.000000     0.491872     0.489779     0.494771
# 50%          1.00000     5.000000     0.491872     0.490126     0.495126
# 75%          1.00000     7.000000     0.492211     0.490286     0.495919
# max          1.00000     9.000000     0.497454     0.583123     0.504982
#
#                 f4           f5           f6           f7           f8  \
# count  8149.000000  8149.000000  8149.000000  8149.000000  8149.000000
# mean      0.492545     0.489068     0.500882     0.499127     0.489572
# std       0.000764     0.002091     0.000595     0.000768     0.000812
# min       0.488261     0.484765     0.497371     0.495818     0.482445
# 25%       0.492096     0.487136     0.500722     0.498742     0.489307
# 50%       0.492950     0.487514     0.500722     0.499337     0.489766
# 75%       0.492985     0.491184     0.501151     0.499337     0.489766
# max       0.496295     0.495822     0.503437     0.504923     0.495602
#
#                 f9
# count  8149.000000
# mean      0.498334
# std       0.000969
# min       0.492209
# 25%       0.498271
# 50%       0.498666
# 75%       0.498811
# max       0.501204

# %%
df_stack_set.to_csv('datasets/train_stack_set.csv')

# %% [markdown]
# # End of stack train setting!!
